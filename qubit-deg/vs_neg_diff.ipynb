# %% [markdown]
# <span style="color:pink; font-size:20px;">File to get plots for Ergotropic Changes vs Change in Correlation Measures of Initial State.</span>
# <!-- <span style="color:yellow; font-size:15px;">vs_neg_diff.ipynb</span> -->

# %%
# Import necessary libraries and functions
import numpy as np
import matplotlib.pyplot as plt
from state_gen import generate_state
from energy import energy, passive_energy_g, passive_energy_l, ergotropy_gap, global_ergo, local_ergo
from local_to import gibbs_states, qubit_ham, LTO_step
from unitary import deg_unitary
from lin_alg import negativity, partial_trace, vn_entropy, rel_entropy, passive_state, mutual_info, correlations

# %%
# Initial parameters and settings
w1=1.0
w2=2.0
w3=1.5 #1.5
w4=2.0 #2.0 #0.5
beta_a=1.0
beta_b=2.0
a = 0.8
p = 0.5
n_terms = 4
N = np.sqrt(a * (1 - a))
np.set_printoptions(precision=4, suppress=True)

kind_dict = {
    1: "product",
    2: "separable",
    3: "schmidt_ent",
    4: "pure_ent",
    5: "werner",
    6: "mixed_ent"
}

# %%
def simulate_and_plot(kind="product", n_samples=200, corr_plot=False):

    neg_list, mi_list, cl_corr_list, disc_list = [], [], [], []
    Rg_lto, Rl_lto, R_gap = [], [], []
    gbound_list = []

    # ----- Initial state -----
    rho12 = generate_state(kind, a=a, n_terms=n_terms, p=p)
    print(f"Initial state:\n{rho12}")

    # ---- reduced states ----
    rho1 = partial_trace(rho12, sys=1)
    rho2 = partial_trace(rho12, sys=0)
    pass_rho_1 = passive_state(rho1)
    pass_rho_2 = passive_state(rho2)

    Hs1 = qubit_ham(w1)
    Hs2 = qubit_ham(w2)
    Hb1 = qubit_ham(w3)
    Hb2 = qubit_ham(w4)
    
    # ----- initial observables ----
    neg_rho = negativity(rho12)
    mi_rho = mutual_info(rho12)
    cl_corr_rho, disc_rho = correlations(rho12)

    E0 = energy(rho12, w1, w2)
    Rg0 = E0 - passive_energy_g(rho12, w1, w2)
    Rl0 = E0 - passive_energy_l(rho12, w1, w2)

    print(f"Initial negativity: {neg_rho:.4f}",)
    print(f"Initial classical correlations: {cl_corr_rho:.4f}",)
    print(f"Initial quantum discord: {disc_rho:.4f}",)
    print(f"Initial mutual information: {mi_rho:.4f}",)


    # ----- Baths (precompute once) -----
    gamma_a, gamma_b = gibbs_states(beta_a, beta_b, w3, w4)

    # ---- local bound ----
    bound_l = (rel_entropy(pass_rho_1, gamma_a)/beta_a) + (rel_entropy(pass_rho_2, gamma_b)/beta_b)

    # ----- Sampling loop -----
    for _ in range(n_samples):

        Ua = deg_unitary(Hs1, Hb1)
        Ub = deg_unitary(Hs2, Hb2)

        sigma, _, _ = LTO_step(rho12, gamma_a, gamma_b, Ua, Ub)

        # ---- observables ----
        neg_list.append(negativity(sigma))
        mi_list.append(mutual_info(sigma))

        if corr_plot:
            cl_corr_sigma, disc_sigma = correlations(sigma)
            cl_corr_list.append(cl_corr_rho - cl_corr_sigma)
            disc_list.append(disc_rho - disc_sigma)

        E_sigma = energy(sigma, w1, w2)
        Rg = E_sigma - passive_energy_g(sigma, w1, w2)
        Rl = E_sigma - passive_energy_l(sigma, w1, w2)

        Rg_lto.append(Rg)
        Rl_lto.append(Rl)
        R_gap.append(Rg - Rl)

        # ---- reduced states ----
        sigma1 = partial_trace(sigma, sys=1)
        sigma2 = partial_trace(sigma, sys=0)

        # ---- global correction term ----
        local_term = (1/beta_a) * (vn_entropy(sigma1) - vn_entropy(rho1)) + (1/beta_b) * (vn_entropy(sigma2) - vn_entropy(rho2))
        energy_term = - passive_energy_g(rho12, w1, w2) + passive_energy_g(sigma, w1, w2)
        bound_g = energy_term + local_term

        gbound_list.append(bound_g)

    return (rho12, neg_rho, mi_rho, Rg0, Rl0, neg_list, mi_list, cl_corr_list, disc_list, Rg_lto, Rl_lto, R_gap, gbound_list, bound_l)

# %%
def plot_lto_results(
    neg_rho, mi_rho, Rg0, Rl0,
    neg_list, mi_list, cl_corr_list, disc_list, 
    Rg_lto, Rl_lto, R_gap, gbound_list, bound_l,
    colors=None,
    marker_size=25,
    alpha=0.5
):
    """
    3×2 visualization of LTO ergotropy behaviour.
    """

    if colors is None:
        colors = {
            "global": "tab:blue",
            "local": "tab:orange",
            "gap": "tab:green",
            "gbound": "tab:red",
            "lbound": "tab:purple"
        }

    # Convert to arrays
    neg_list = np.array(neg_list)
    mi_list = np.array(mi_list)
    Rg_lto = np.array(Rg_lto)
    Rl_lto = np.array(Rl_lto)
    R_gap = np.array(R_gap)
    gbound_list = np.array(gbound_list)
    cl_corr = np.array(cl_corr_list)
    disc = np.array(disc_list)

    ΔN = neg_rho - neg_list
    ΔI = mi_rho - mi_list
    ΔRg = Rg_lto - Rg0
    ΔRl = Rl_lto - Rl0

    fig, axs = plt.subplots(7, 2, figsize=(15, 30))

    # ---------------- Row 1 ----------------

    # Global ergotropy
    axs[0,0].scatter(ΔN, Rg_lto, s=marker_size,
                     color=colors["global"], alpha=alpha, label="Rg after LTO")
    axs[0,0].axhline(Rg0, linestyle="--", color="black", label="Initial Rg")
    axs[0,0].set_title("Global ergotropy vs ΔN")
    axs[0,0].set_xlabel("ΔN")
    axs[0,0].set_ylabel("Rg")
    axs[0,0].legend()
    axs[0,0].grid(True)

    # Global ergotropy
    axs[0,1].scatter(ΔI, Rg_lto, s=marker_size,
                     color=colors["global"], alpha=alpha, label="Rg after LTO")
    axs[0,1].axhline(Rg0, linestyle="--", color="black", label="Initial Rg")
    axs[0,1].set_title("Global ergotropy vs ΔI")
    axs[0,1].set_xlabel("ΔI")
    axs[0,1].set_ylabel("Rg")
    axs[0,1].legend()
    axs[0,1].grid(True)

    # ---------------- Row 2 ----------------

    # Local ergotropy
    axs[1,0].scatter(ΔN, Rl_lto, s=marker_size,
                     color=colors["local"], alpha=alpha, label="Rl after LTO")
    axs[1,0].axhline(Rl0, linestyle="--", color="black", label="Initial Rl")
    axs[1,0].set_title("Local ergotropy vs ΔN")
    axs[1,0].set_xlabel("ΔN")
    axs[1,0].set_ylabel("Rl")
    axs[1,0].legend()
    axs[1,0].grid(True)

    # Local ergotropy
    axs[1,1].scatter(ΔI, Rl_lto, s=marker_size,
                     color=colors["local"], alpha=alpha, label="Rl after LTO")
    axs[1,1].axhline(Rl0, linestyle="--", color="black", label="Initial Rl")
    axs[1,1].set_title("Local ergotropy vs ΔI")
    axs[1,1].set_xlabel("ΔI")
    axs[1,1].set_ylabel("Rl")
    axs[1,1].legend()
    axs[1,1].grid(True)

    # ---------------- Row 3 ----------------

    # ΔRg with bound
    axs[2,0].scatter(ΔN, ΔRg, s=marker_size,
                     color=colors["global"], alpha=alpha, label="ΔRg")
    axs[2,0].scatter(ΔN, gbound_list, s=marker_size,
                     color=colors["gbound"], alpha=alpha, label="Global bound")
    axs[2,0].set_title("ΔRg vs ΔN")
    axs[2,0].set_xlabel("ΔN")
    axs[2,0].set_ylabel("ΔRg")
    axs[2,0].legend()
    axs[2,0].grid(True)

    # ΔRg with bound
    axs[2,1].scatter(ΔI, ΔRg, s=marker_size,
                     color=colors["global"], alpha=alpha, label="ΔRg")
    axs[2,1].scatter(ΔI, gbound_list, s=marker_size,
                     color=colors["gbound"], alpha=alpha, label="Global bound")
    axs[2,1].set_title("ΔRg vs ΔI")
    axs[2,1].set_xlabel("ΔI")
    axs[2,1].set_ylabel("ΔRg")
    axs[2,1].legend()
    axs[2,1].grid(True)

    # ---------------- Row 4 ----------------

    # ΔRl with bound
    axs[3,0].scatter(ΔN, ΔRl, s=marker_size,
                     color=colors["local"], alpha=alpha, label="ΔRl")
    axs[3,0].axhline(bound_l, linestyle="--", color="purple", label="Local bound")
    axs[3,0].set_title("ΔRl vs ΔN")
    axs[3,0].set_xlabel("ΔN")
    axs[3,0].set_ylabel("ΔRl")
    axs[3,0].legend()
    axs[3,0].grid(True)

    # ΔRl with bound
    axs[3,1].scatter(ΔI, ΔRl, s=marker_size,
                     color=colors["local"], alpha=alpha, label="ΔRl")
    axs[3,1].axhline(bound_l, linestyle="--", color="purple", label="Local bound")
    axs[3,1].set_title("ΔRl vs ΔI")
    axs[3,1].set_xlabel("ΔI")
    axs[3,1].set_ylabel("ΔRl")
    axs[3,1].legend()
    axs[3,1].grid(True)

    # --------------- Row 5 ------------------------

    # Gap
    axs[4,0].scatter(ΔN, R_gap, s=marker_size,
                     color=colors["gap"], alpha=alpha, label="Rg − Rl")
    axs[4,0].axhline(Rg0 - Rl0, linestyle="--", color="black", label="Initial gap")
    axs[4,0].set_title("Ergotropy gap vs ΔN")
    axs[4,0].set_xlabel("ΔN")
    axs[4,0].set_ylabel("Gap")
    axs[4,0].legend()
    axs[4,0].grid(True)

    # Gap
    axs[4,1].scatter(ΔI, R_gap, s=marker_size,
                     color=colors["gap"], alpha=alpha, label="Rg − Rl")
    axs[4,1].axhline(Rg0 - Rl0, linestyle="--", color="black", label="Initial gap")
    axs[4,1].set_title("Ergotropy gap vs ΔI")
    axs[4,1].set_xlabel("ΔI")
    axs[4,1].set_ylabel("Gap")
    axs[4,1].legend()
    axs[4,1].grid(True)


    # --------------- Row 6 ------------------------
    lims2 = [min(ΔN.min(), ΔI.min()) - 0.01,
            max(ΔN.max(), ΔI.max()) + 0.01]

    for col, (c_arr, c_label, ttl) in enumerate([
        (ΔRg, r"$\Delta R_g$", "ΔN vs ΔI (colored by ΔRg)"),
        (ΔRl, r"$\Delta R_l$", "ΔN vs ΔI (colored by ΔRl)"),
    ]):
        ax  = axs[5, col]
        sc  = ax.scatter(ΔN, ΔI, c=c_arr, cmap='viridis',
                        s=marker_size, alpha=alpha,
                        linewidths=0.4, edgecolors='white', zorder=3)
        cbar = fig.colorbar(sc, ax=ax, pad=0.02)
        cbar.set_label(c_label, fontsize=10)
        cbar.ax.tick_params(labelsize=8)
        ax.plot(lims2, lims2, color='#BDBDBD', linewidth=0.9,
                linestyle='--', zorder=1, label=r"$\Delta N = \Delta I$")
        ax.axvline(0, color='#BDBDBD', linewidth=0.8, linestyle=':', zorder=1)
        ax.set_xlim(lims2);  ax.set_ylim(lims2)
        ax.set_xlabel(r"$\Delta N$",  fontsize=10)
        ax.set_ylabel(r"$\Delta I$",  fontsize=10)
        ax.set_title(ttl,             fontsize=10)
        ax.legend(fontsize=8, frameon=True)
        ax.grid(True)

    if disc.size > 0:
        # --------------- Row 7 ------------------------
        lims2 = [min(cl_corr.min(), disc.min()) - 0.01,
                max(cl_corr.max(), disc.max()) + 0.01]

        for col, (c_arr, c_label, ttl) in enumerate([
            (ΔRg, r"$\Delta R_g$", "ΔC vs ΔQ (colored by ΔRg)"),
            (ΔRl, r"$\Delta R_l$", "ΔC vs ΔQ (colored by ΔRl)"),
        ]):
            ax  = axs[6, col]
            sc  = ax.scatter(cl_corr, disc, c=c_arr, cmap='viridis',
                            s=marker_size, alpha=alpha,
                            linewidths=0.4, edgecolors='white', zorder=3)
            cbar = fig.colorbar(sc, ax=ax, pad=0.02)
            cbar.set_label(c_label, fontsize=10)
            cbar.ax.tick_params(labelsize=8)
            ax.plot(lims2, lims2, color='#BDBDBD', linewidth=0.9,
                    linestyle='--', zorder=1, label=r"$\Delta C = \Delta Q$")
            ax.axvline(0, color='#BDBDBD', linewidth=0.8, linestyle=':', zorder=1)
            ax.set_xlim(lims2);  ax.set_ylim(lims2)
            ax.set_xlabel(r"$\Delta C$",  fontsize=10)
            ax.set_ylabel(r"$\Delta Q$",  fontsize=10)
            ax.set_title(ttl,             fontsize=10)
            ax.legend(fontsize=8, frameon=True)
            ax.grid(True)

    else: 
        axs[6, 0].axis('off')
        axs[6, 1].axis('off')

    plt.tight_layout()
    plt.show()

# %%
# Defining Parameters

# Parameters for Degenerate Hamiltonians
w1=1.0
w2=2.0
# w3=1.5 #1.0 #1.5
# w4=0.5 #2.0 #0.5
w3 = 1.0
w4 = 2.0

# Inverse temperatures
beta_a=1.0
beta_b=2.0

# State parameters
a = 0.8
p = 0.5
n_terms = 4
N = np.sqrt(a * (1 - a))
np.set_printoptions(precision=4, suppress=True)

kind_dict = {
    1: "product",
    2: "separable",
    3: "schmidt_ent",
    4: "pure_ent",
    5: "werner",
    6: "mixed_ent",
    7: "random"
}

# %%
# Run the simulation and plot results for a specific state type (e.g., "pure_ent")
(rho12, neg_rho, mi_rho, Rg0, Rl0, neg_list, mi_list, cl_corr_list, disc_list, Rg_lto, Rl_lto, R_gap,
gbound_list, bound_l) = simulate_and_plot(kind=kind_dict[4], n_samples=500, corr_plot=True)

print(f'rho12: \n{rho12}')
print(partial_trace(rho12, sys=1))
print(partial_trace(rho12, sys=0))

plot_lto_results(neg_rho, mi_rho, Rg0, Rl0, neg_list, mi_list, cl_corr_list, disc_list, Rg_lto, Rl_lto, R_gap, gbound_list, bound_l)
# Out:
# Initial state:
# [[ 0.0574+0.j     -0.0511+0.1146j  0.0456-0.0989j -0.0048-0.1628j]
#  [-0.0511-0.1146j  0.2743-0.j     -0.2379-0.003j  -0.3206+0.1546j]
#  [ 0.0456+0.0989j -0.2379+0.003j   0.2064-0.j      0.2764-0.1376j]
#  [-0.0048+0.1628j -0.3206-0.1546j  0.2764+0.1376j  0.4619+0.j    ]]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:00<00:00, 469.03trial/s]
# Initial negativity: 0.3781
# Initial classical correlations: 0.4603
# Initial quantum discord: 0.4603
# Initial mutual information: 0.9206
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.94trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.33trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.33trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 147.73trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 136.09trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.41trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.31trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.57trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 127.48trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 136.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.06trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 155.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 132.07trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.08trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 156.33trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.71trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 142.91trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 133.34trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.99trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:03<00:00, 59.82trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 93.43trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.86trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 98.68trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.99trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.61trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.15trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.98trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 85.45trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 136.57trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 119.82trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 144.96trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.09trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 161.17trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 156.76trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 151.88trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 148.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.31trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 139.88trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.64trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 144.94trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 110.95trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.61trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.96trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 159.11trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 113.11trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.71trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 143.56trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 144.91trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.09trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 147.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.13trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 151.77trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 155.97trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 145.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 146.21trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.50trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 147.59trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 113.98trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.87trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.03trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.68trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.14trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 152.01trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.25trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 144.86trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.02trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.15trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.75trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.55trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.18trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.16trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.57trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.40trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 155.78trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 143.59trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 116.93trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 144.34trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 132.78trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 144.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 113.19trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:03<00:00, 63.21trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 127.62trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.34trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.16trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.46trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.64trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 142.23trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 146.11trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 144.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 145.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.99trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 105.92trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 136.12trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 133.97trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.92trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 74.28trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 97.50trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.11trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.83trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.74trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 74.96trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 111.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.51trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 145.51trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.51trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 127.76trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 138.86trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.18trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.16trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.36trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.01trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 77.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.42trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.15trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.03trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 109.98trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.65trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.02trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 145.47trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 151.06trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.48trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.81trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.30trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 113.80trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.98trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.63trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.29trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.70trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 104.79trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 133.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.01trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 106.03trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 105.66trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.40trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.58trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.59trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.54trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.12trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.54trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.88trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.06trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 143.35trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 90.97trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 133.56trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 103.18trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 139.62trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 113.63trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 127.71trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.76trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.11trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 101.93trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 116.23trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.15trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 96.77trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 116.10trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.10trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.86trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 109.14trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.14trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 106.36trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 88.92trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.30trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.11trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 108.96trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.29trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 87.72trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 85.71trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 108.10trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 119.93trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 94.70trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 103.99trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 108.39trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.97trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.81trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 119.04trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.87trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.30trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.94trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 105.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.01trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 79.15trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.02trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.62trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.21trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 73.41trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.70trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.14trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 142.88trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.79trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 82.43trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.66trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.23trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.25trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 132.64trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 98.17trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.17trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 96.19trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.89trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.77trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 143.48trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.40trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 71.05trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.50trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.49trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.75trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.83trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 138.42trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 103.95trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.70trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.39trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.99trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.86trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 104.36trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 143.23trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 94.07trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 96.65trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 138.97trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 133.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 127.22trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.84trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.48trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.24trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.58trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.23trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 103.84trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.46trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.75trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.02trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.07trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.58trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 139.65trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.47trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.38trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 103.73trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 136.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 76.38trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 145.17trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 73.55trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.94trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.02trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 93.51trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 101.47trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.29trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.10trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.23trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.33trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.41trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 138.85trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.72trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 109.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.07trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.06trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 133.63trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.45trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.81trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 107.92trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.83trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:03<00:00, 61.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 94.64trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 89.64trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 84.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 139.33trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.90trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.77trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.31trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.67trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.51trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.45trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.78trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.16trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 119.21trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.54trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.21trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.72trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 94.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 116.40trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.14trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.42trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.24trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 89.30trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 127.55trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.07trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 138.17trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 106.90trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 146.91trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 133.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 95.85trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 110.54trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 110.20trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 70.31trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.50trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 128.49trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 98.56trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.72trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.98trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.19trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.61trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.71trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 111.05trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 151.07trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.20trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.85trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.39trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 142.14trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 119.96trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 116.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 72.50trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 108.62trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.97trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 142.18trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.41trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.78trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 136.66trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 111.70trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.82trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.49trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.51trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.84trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 154.67trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 144.24trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 142.71trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 140.14trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.87trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 111.40trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.75trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.23trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 105.74trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 73.12trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 89.56trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 104.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 101.11trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 111.34trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 116.51trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 95.74trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 119.28trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.33trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 95.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 99.16trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 107.77trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 96.12trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 105.78trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 98.57trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.66trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 108.46trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 84.72trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 109.18trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 109.81trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 98.76trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.57trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 103.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 103.04trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.32trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 82.49trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.85trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 109.58trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.23trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 86.61trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.08trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.42trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:03<00:00, 54.20trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 142.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.24trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.10trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 113.02trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.57trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 146.19trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.89trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.95trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.48trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 104.48trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 107.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.74trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 93.25trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 97.17trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 148.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.46trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 145.74trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.83trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 148.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 104.04trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.03trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 155.51trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 109.81trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 90.79trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.32trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.22trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.55trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 116.63trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.65trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.77trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.37trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 99.77trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 111.95trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.13trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.20trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.73trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 99.02trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.25trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.15trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.59trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 149.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 149.99trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.89trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.42trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.77trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.27trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 134.25trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 98.69trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 120.76trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 82.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.35trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.89trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.14trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 83.40trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.97trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 141.18trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 90.84trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.31trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 137.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.25trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.58trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.16trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 122.78trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 113.97trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 129.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 135.44trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 127.60trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 106.04trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.99trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 133.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 100.33trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 130.52trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.42trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 118.20trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.99trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 104.67trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 82.69trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 97.71trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 102.02trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:03<00:00, 66.55trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:03<00:00, 65.53trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 92.58trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 81.26trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 112.00trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 110.07trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 115.30trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 96.17trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 131.49trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 124.07trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 138.62trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.36trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.76trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 108.40trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.32trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.89trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 108.03trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 114.79trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 117.96trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 121.10trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:02<00:00, 73.69trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 125.68trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 126.75trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 123.88trial/s]
# Optimizing classical correlations: 100%|██████████| 200/200 [00:01<00:00, 127.54trial/s]
# rho12:
# [[ 0.0574+0.j     -0.0511+0.1146j  0.0456-0.0989j -0.0048-0.1628j]
#  [-0.0511-0.1146j  0.2743-0.j     -0.2379-0.003j  -0.3206+0.1546j]
#  [ 0.0456+0.0989j -0.2379+0.003j   0.2064-0.j      0.2764-0.1376j]
#  [-0.0048+0.1628j -0.3206-0.1546j  0.2764+0.1376j  0.4619+0.j    ]]
# [[ 0.3317-0.j     -0.275 +0.0557j]
#  [-0.275 -0.0557j  0.6683-0.j    ]]
# [[0.2638-0.j    0.2253-0.023j]
#  [0.2253+0.023j 0.7362-0.j   ]]
